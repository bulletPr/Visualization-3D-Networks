# %%
cd /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2
# Out:
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2

# %%
# !ls
# Out:
# data	    LICENSE  provider.py  test_partseg.py  train_partseg.py  visualizer
# data_utils  log      __pycache__  test_semseg.py   train_semseg.py
# demo.py     models   test_cls.py  train_cls.py	   Untitled0.ipynb

# %%
# !python train_cls.py
# Out:
# PARAMETER ...
# Namespace(batch_size=16, decay_rate=1e-06, epoch=250, gpu='0', learning_rate=0.001, log_dir=None, model='pointnet_cam', normal=False, num_point=1024, optimizer='Adam')
# Load dataset ...
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2/data_utils/ModelNetDataLoader.py:82: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_name)
# No existing model, starting training from scratch...
# Epoch 1 (1/250):
# ...

# %%
# !python demo.py
# Out:
# PARAMETER ...
# Namespace(batch_size=16, gpu='0', log_dir='2020-04-27_12-27', normal=False, num_point=1024, num_votes=3)
# Load dataset ...
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2/data_utils/ModelNetDataLoader.py:82: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_name)
# PointNetEncoder(
#   (stn): STN3d(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=1024, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
# ...

# %%
#[con_0_1_4]
# !python demo.py
# Out:
# PARAMETER ...
# Namespace(batch_size=16, gpu='0', log_dir='2020-04-27_12-27', normal=False, num_point=1024, num_votes=3)
# Load dataset ...
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2/data_utils/ModelNetDataLoader.py:82: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_name)
# PointNetEncoder(
#   (stn): STN3d(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=1024, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
# ...

# %%
# !python demo.py
# Out:
# PARAMETER ...
# Namespace(batch_size=16, gpu='0', log_dir='2020-04-27_12-27', normal=False, num_point=1024, num_votes=3)
# Load dataset ...
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2/data_utils/ModelNetDataLoader.py:82: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_name)
# PointNetEncoder(
#   (stn): STN3d(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=1024, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
# ...

# %%
# !python demo.py
# Out:
# PARAMETER ...
# Namespace(batch_size=16, gpu='0', log_dir='2020-04-27_12-27', normal=False, num_point=1024, num_votes=3)
# Load dataset ...
# /content/drive/My Drive/Pointnet_Pointnet2_pytorch-master2/data_utils/ModelNetDataLoader.py:82: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(h5_name)
# PointNetEncoder(
#   (stn): STN3d(
#     (conv1): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#     (conv3): Conv1d(128, 1024, kernel_size=(1,), stride=(1,))
#     (fc1): Linear(in_features=1024, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=256, bias=True)
# ...
